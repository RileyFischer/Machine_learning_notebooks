# %% [markdown]
# # Stacked Autoencoder Digits Example
# **Train Stacked Autoencoders for Image Classification**
#
# This example shows how to train stacked autoencoders to classify images of digits.
#
# Neural networks with multiple hidden layers can be useful for solving classification problems with complex data, such as images. Each layer can learn features at a different level of abstraction. however, training neural networks with multiple hidden layers can be difficult in practice. One way to effectively train a neural network with multiple layers is by training one layer at a time. You can achieve this by training a special type of network known as an autoencoder for each desired hidden layer.
#
# This example shows you how to train a neural network with two hidden layers to classify digits in the images. First you train the hidden layers individually in an unsupervised fashion using autoencoders. Then you train a final softmax layer, and join the layers together to form a stacked network, which you train one final time in a supervised fashion.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
## Data set
# This example uses synthetic data throughout, for training and testing.
# The synthetic images have been generated by applying random affine
# transformations to digit images created using different fonts.
# 
# Each digit image is 28-by-28 pixels, and there are 5,000 training
# examples. You can load the training data, and view some of the images.

# Load the training and testing data into memory.
drive.mount('/content/drive')
with open('/content/drive/My Drive/Colab Notebooks/data/xTrain.csv', 'r') as f: 
  x_train = np.genfromtxt(f, dtype='f4', delimiter=',').T
with open('/content/drive/My Drive/Colab Notebooks/data/tTrain.csv', 'r') as f: 
  y_train = np.genfromtxt(f, dtype='f4', delimiter=',').T
with open('/content/drive/My Drive/Colab Notebooks/data/xTest.csv', 'r') as f: 
  x_test = np.genfromtxt(f, dtype='f4', delimiter=',').T
with open('/content/drive/My Drive/Colab Notebooks/data/tTest.csv', 'r') as f: 
  y_test = np.genfromtxt(f, dtype='f4', delimiter=',').T

print(x_train.shape)
print(x_test.shape)


# display some of the training image
for i in range(20):
  X_img = x_train[i].reshape(28,28)
  plt.subplot(4,5,i+1)
  fig = plt.imshow(X_img,cmap='gray')
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)

plt.show()  

# Reshape and normalize keras data.
#x_train = (x_train.astype('float32')/255).reshape((len(x_train), np.prod(x_train.shape[1:])))
#x_test = (x_test.astype('float32')/255).reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Mounted at /content/drive
# (5000, 784)
# (5000, 784)

# %% [markdown]
# The labels for the images are stored in a 10-by-5000 matrix, where in  every column a single element will be 1 to indicate the class that the  digit belongs to, and all other elements in the column will be 0. It  should be noted that if the tenth element is 1, then the digit image is a zero.

# %%
## Training the first autoencoder
# Begin by training a sparse autoencoder on the training data without using
# the labels
# 
# An autoencoder is a neural network which attempts to replicate its input
# at its output. Thus, the size of its input will be the same as the size
# of its output. When the number of neurons in the hidden layer is less
# than the size of the input, the autoencoder learns a compressed
# representation of the input. 
# 
# Nueral networkds have weights randomly initialized before training
# Therefore the results from training are different each time. To avoid
# this behavior, explicitly set the random number generator seed.
np.random.seed(0)

# %%
## 
# Set the size of the hidden layer for the autoencoder. For the autoencoder
# that you are going to train, it is a good idea to make this smaller than
# the input size.
hiddenSize1 = 100

# %%
import keras
from keras import layers
## 
# The type of autoencoder that you will train is an autoencoder. The autoencoder
# consists of two layers, the first layer consists of 100 sigmoid neurons which
# encodes the image into a 100 length feature vector. 
# The decoder layer learns the mapping from the encoded feature vector back to 
# the original image. 

in_size = 784
#Autoencoder layer 1
in_img = keras.Input(shape=(in_size,))  # Specify input shape
encoded = layers.Dense(hiddenSize1, activation='sigmoid',name='Encoder')(in_img) # Encoder Layer
decoded = layers.Dense(in_size, activation='sigmoid', name = 'Decoder')(encoded)  # decoder layer

# Create the network model
autoencoder = keras.Model(in_img, decoded)
# We also create a model for only the encoder section of the network
encoder = keras.Model(in_img, encoded)
# Initialize the weights and specify our loss function (for measuring training 
# error)
autoencoder.compile(optimizer='adam', loss='MeanSquaredError')
# Run unsupervised training on the training set. We run the training for 100 epochs.
autoencoder.fit(x_train, x_train, epochs=100, batch_size=256,shuffle=True)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 10ms/step - loss: 0.1468
# Epoch 2/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0569
# Epoch 3/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0468
# Epoch 4/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0454
# Epoch 5/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0450
# Epoch 6/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0447
# Epoch 7/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0445
# Epoch 8/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0443
# Epoch 9/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0441
# Epoch 10/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0440
# Epoch 11/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0438
# Epoch 12/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0437
# Epoch 13/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0435
# Epoch 14/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0434
# Epoch 15/100
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0432
# Epoch 16/100
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0430
# Epoch 17/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0427
# Epoch 18/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0425
# Epoch 19/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0422
# Epoch 20/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0419
# Epoch 21/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0416
# Epoch 22/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0413
# Epoch 23/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0410
# Epoch 24/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0406
# Epoch 25/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0402
# Epoch 26/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0399
# Epoch 27/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0395
# Epoch 28/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0391
# Epoch 29/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0386
# Epoch 30/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0382
# Epoch 31/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0378
# Epoch 32/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0373
# Epoch 33/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0368
# Epoch 34/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0363
# Epoch 35/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0359
# Epoch 36/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0354
# Epoch 37/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0349
# Epoch 38/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0344
# Epoch 39/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0340
# Epoch 40/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0335
# Epoch 41/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0330
# Epoch 42/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0326
# Epoch 43/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0321
# Epoch 44/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0317
# Epoch 45/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0313
# Epoch 46/100
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0308
# Epoch 47/100
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0304
# Epoch 48/100
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0300
# Epoch 49/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0296
# Epoch 50/100
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0292
# Epoch 51/100
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0287
# Epoch 52/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0284
# Epoch 53/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0280
# Epoch 54/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0276
# Epoch 55/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0272
# Epoch 56/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0269
# Epoch 57/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0265
# Epoch 58/100
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0261
# Epoch 59/100
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0258
# Epoch 60/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0254
# Epoch 61/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0251
# Epoch 62/100
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0247
# Epoch 63/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0244
# Epoch 64/100
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0240
# Epoch 65/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0237
# Epoch 66/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0234
# Epoch 67/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0231
# Epoch 68/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0227
# Epoch 69/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0224
# Epoch 70/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0221
# Epoch 71/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0219
# Epoch 72/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0216
# Epoch 73/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0213
# Epoch 74/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0210
# Epoch 75/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0208
# Epoch 76/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0205
# Epoch 77/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0202
# Epoch 78/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0200
# Epoch 79/100
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0198
# Epoch 80/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0195
# Epoch 81/100
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0193
# Epoch 82/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0191
# Epoch 83/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0189
# Epoch 84/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0187
# Epoch 85/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0185
# Epoch 86/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0183
# Epoch 87/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0181
# Epoch 88/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0179
# Epoch 89/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0177
# Epoch 90/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0175
# Epoch 91/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0173
# Epoch 92/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0171
# Epoch 93/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0170
# Epoch 94/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0168
# Epoch 95/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0166
# Epoch 96/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0165
# Epoch 97/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0163
# Epoch 98/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0161
# Epoch 99/100
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0160
# Epoch 100/100
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0158

# %%
##
# You can view a diagram of the autoencoder. The autoencoder is comprised
# of an encoder followed by a decoder. The encoder maps an input to a 
# hidden representation, and the decoder attempts to reverse this mapping
# to reconstruct the original input.

from tensorflow.keras.utils import plot_model
plot_model(autoencoder, to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
## Visualizing the weights of the first autoencoder
# The mapping learned by the encoder part of an autoencoder can be useful
# for extracting features from data. Each neuron in the encoder has a
# vector of weights associated with it which will be tuned to respond to a
# particular visual feature. You can view a representation of these
# features.

import math
n_cols = math.ceil(hiddenSize1 / 10)
fig = plt.figure(figsize=(12,12))


for i in range(hiddenSize1):
  w = autoencoder.layers[1].get_weights()[0][:,i].reshape(28,28)
  plt.subplot(n_cols, 10, i+1)
  plt.imshow(w,cmap='gray')
  plt.axis("off")
  
plt.show()

# %%
##
# The 100-dimensional output from the hidden layer of the autoencoder is a
# compressed version of the input. Train the next autoencoder on a set of these
# vectors extracted from the training data. First, you must use the encoder
# from the trained autoencoder to generate the features.
feat1 = encoder.predict(x_train)
hiddenSize2 = 50

# %%
## Training the second autoencoder
# After training the first autoencoder, you train the second autoencoder in
# a similar way. The main difference is that you use the features that were
# generated from the first autoencoder as the training data in the second
# autoencoder. Also, you decrease the size of the hidden representation to
# 50, so that the encoder in the second autoencoder learns an even smaller
# representation of the input data.

in_img2 = keras.Input(shape=(hiddenSize1,))
encoded2 = layers.Dense(hiddenSize2, activation='sigmoid',name="Encoder_2")(in_img2)
decoded2 = layers.Dense(hiddenSize1, activation='sigmoid',name= "Decoder_2")(encoded2)

autoencoder2 = keras.Model(in_img2, decoded2)
encoder2 = keras.Model(in_img2, encoded2)
autoencoder2.compile(optimizer='adam', loss='MeanSquaredError')


autoencoder2.fit(feat1, feat1, epochs=100, batch_size=256,shuffle=True)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.1481
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0925
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0702
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0640
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0620
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0610
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0604
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0599
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0594
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0590
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0585
# Epoch 12/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0579
# Epoch 13/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0573
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0566
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0558
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0550
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0541
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0531
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0511
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0500
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0490
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0479
# Epoch 24/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0468
# Epoch 25/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0457
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0446
# Epoch 27/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0436
# Epoch 28/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0425
# Epoch 29/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0415
# Epoch 30/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0405
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0395
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 33/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0376
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0367
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0358
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0349
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0332
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0323
# Epoch 40/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0315
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 43/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0291
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0284
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0269
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 50/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0243
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0231
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 56/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0209
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0199
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0189
# Epoch 61/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0185
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 64/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0173
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 67/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0162
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0159
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 73/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0144
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 79/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0129
# Epoch 80/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0127
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 83/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0120
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 86/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0114
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 89/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 94/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0095
# Epoch 99/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0092

# %%
##
# Once again, you can view the autoencoder structure using plot model
plot_model(autoencoder2, to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
##
# You can extract a second set of features by passing the previous set
# through the encoder from the second autoencoder.
feat2 = encoder2.predict(feat1)

# %%
from tensorflow.keras.utils import to_categorical
##
# The original vectors in the training data had 784 dimensions. After
# passing them through the first encoder, this was reduced to 100
# dimensions. After using the second encoder, this was reduced again to 50
# dimensions. You can now train a final layer to classify these 
# 50-dimensional vectors into different digit classes.

## Training the final softmax layer
# Train a softmax layer to classify the 50-dimensional feature vectors.
# Unlike the autoencoders, you train the softmax layer in a supervised
# fashion using labels for the training data.

soft_in = keras.Input(shape=(hiddenSize2,))
soft_layer = layers.Dense(10,activation='softmax', name="Softmax")(soft_in)

softnet = keras.Model(soft_in, soft_layer)
softnet.compile(optimizer='adam', loss='MeanSquaredError')

softnet.fit(feat2, y_train, epochs=100, batch_size=256,shuffle=True)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0934
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0914
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0907
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0901
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0896
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0890
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0885
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0879
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0873
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0867
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0861
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0855
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0850
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0843
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0837
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0831
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0825
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0819
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0813
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0808
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0802
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0796
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0790
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0785
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0780
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0775
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0760
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0756
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0752
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0747
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0743
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0739
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0735
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0732
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0728
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0724
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0721
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0718
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0715
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0712
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0709
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0706
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0704
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0701
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0693
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0691
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0685
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0682
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0681
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0679
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0677
# Epoch 58/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0675
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0673
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0671
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0668
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0666
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0665
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0663
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0662
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0660
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0657
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0656
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0655
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0653
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0652
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0651
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0650
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0649
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0647
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0647
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0645
# Epoch 80/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0644
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0643
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0642
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0641
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0640
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0638
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0637
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0635
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0634
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0634
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0633
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0631
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0630
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0629
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0629
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0628
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0627
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0626

# %%
##
# Viewing the structure of the sofmax network
plot_model(softnet, to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
enc1 = encoder.predict(x_test)
enc2 = encoder2.predict(enc1)
y_out = softnet.predict(enc2)
y_classified = np.argmax(y_out, axis=1)

# %%
## Forming a stacked neural network
# You have trained three separate components of a stacked neural network in
# isolation. 

# As was explained, the encoders from the autoencoders have been used to
# extract features. You can stack the encoders from the autoencoders 
# together with the softmax layer to form a stacked network for classification.

#First we must specify the structure of our stacked model
stacked_in = keras.Input(shape=(in_size,))
layer1 = layers.Dense(hiddenSize1, activation='sigmoid')(stacked_in)
layer2 = layers.Dense(hiddenSize2, activation='sigmoid')(layer1)
layer3 = layers.Dense(10, activation='softmax')(layer2)

#Then the model must be created and initialized.
stacked_ae = keras.Model(stacked_in, layer3)
stacked_ae.compile(optimizer="adam", loss = "MeanSquaredError")

# Then we transfer the weights from our previously trained layers. 
stacked_ae.layers[0].set_weights(autoencoder.layers[0].get_weights())
stacked_ae.layers[1].set_weights(autoencoder.layers[1].get_weights())
stacked_ae.layers[2].set_weights(autoencoder2.layers[1].get_weights())
stacked_ae.layers[3].set_weights(softnet.layers[1].get_weights())

# %%
##
# View the stacked network
plot_model(stacked_ae, to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
##
# You can visualize the results with a confusion matrix.
import seaborn as sn
def plot_confusion_matrix(y_classified, y_true):
  # Compute confusion matrix
  c_mat = np.zeros((10,10))
  for i in range(len(y_true)):
    c_mat[y_classified[i], y_true[i] ] += 1

  group_counts = ["{0:0.0f}".format(value) for value in c_mat.flatten()]
  group_percentages = ["{0:.2%}".format(value) for value in c_mat.flatten()/np.sum(c_mat)]
  labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
  labels = np.asarray(labels).reshape(c_mat.shape[0], c_mat.shape[1])

  accuracy = (np.sum(np.logical_and(y_classified, y_true))/ len(y_true)) * 100

  plt.figure(figsize=(12,10))
  sn.heatmap(c_mat, annot=labels, fmt='', cmap='rocket_r')
  plt.title("Confusion Matrix")
  plt.ylabel('Output Class')
  plt.xlabel('Target Class \n Accuracy: ' + '%.2f'%accuracy + "%")

# %%
# Run x_Test through the stacked autoencoder. 
y_stacked = stacked_ae.predict(x_test)
# we need to convert it from 1 hot format back to the mnist labeling.
y_classified = np.argmax(y_stacked, axis=1)


y_true = np.argmax(y_test, axis=1)
# plot confusion matrix
plot_confusion_matrix(y_classified, y_true)

# %%
## Fine tuning the stacked neural network
# The results for the stacked neural network can be improved by performing
# backpropagation on the whole multilayer network. This process is often
# referred to as fine tuning.
#
# You fine tune the network by retraining it on the training data in a
# supervised fashion. Before you can do this, you have to reshape the
# training images into a matrix, as was done for the test images.

stacked_ae.fit(x_train, y_train, epochs=100,batch_size = 256, shuffle=True)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0613
# Epoch 2/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0580
# Epoch 3/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0554
# Epoch 4/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0532
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0511
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0492
# Epoch 7/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0473
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0455
# Epoch 9/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0439
# Epoch 10/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0423
# Epoch 11/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0407
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0392
# Epoch 13/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0379
# Epoch 14/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0365
# Epoch 15/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0353
# Epoch 16/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0340
# Epoch 17/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0328
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0316
# Epoch 19/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0305
# Epoch 20/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0295
# Epoch 21/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0284
# Epoch 22/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0273
# Epoch 23/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0264
# Epoch 24/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0255
# Epoch 25/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0245
# Epoch 26/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0237
# Epoch 27/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 28/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 29/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0212
# Epoch 30/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0205
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0197
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0190
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0183
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0177
# Epoch 35/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0170
# Epoch 36/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0165
# Epoch 37/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0159
# Epoch 38/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0153
# Epoch 39/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0147
# Epoch 40/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0142
# Epoch 41/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0137
# Epoch 42/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0132
# Epoch 43/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0127
# Epoch 44/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0123
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0118
# Epoch 46/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0113
# Epoch 47/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0109
# Epoch 48/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0105
# Epoch 49/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0101
# Epoch 50/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 51/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0092
# Epoch 52/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0089
# Epoch 53/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0085
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 55/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 56/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 57/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 58/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 59/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 60/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 61/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0061
# Epoch 62/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0059
# Epoch 63/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 64/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0055
# Epoch 65/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0053
# Epoch 66/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 67/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0049
# Epoch 68/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 69/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 70/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0044
# Epoch 71/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 72/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 73/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 74/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 75/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 76/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 77/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 78/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 79/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 80/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0032
# Epoch 81/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0031
# Epoch 82/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 83/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0029
# Epoch 84/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0028
# Epoch 85/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0028
# Epoch 86/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 87/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 88/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 89/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 90/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0024
# Epoch 91/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 92/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 93/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 94/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 95/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 97/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 98/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 99/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 100/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0017

# %%
# Finally,view the results of the fine tuning on the confusion matrix. 
y_stacked = stacked_ae.predict(x_test)
y_classified = np.argmax(y_stacked, axis=1)

# plot confusion matrix
y_true = np.argmax(y_test, axis=1)
plot_confusion_matrix(y_classified, y_true)

# %%
drive.flush_and_unmount()

# %% [markdown]
# ## Summary
# This example showed how to train a stacked neural network to classify digits
# in images using autoencoders. The steps that have been
# outlined can be applied to other similar problems, such as classifying
# images of letters, or even small images of objects of a specific
# category.
